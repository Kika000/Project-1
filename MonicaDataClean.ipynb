# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#load csv data in dataframe
education_index_file = "data/Education Index.csv"
education_index_df = pd.read_csv(education_index_file)
education_index_df.head()
# Out:
#    Education Index    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  HDI Rank (2017)       Country    1990.000    1991.000    1992.000
# 1              168   Afghanistan       0.122       0.133       0.145
# 2               68       Albania       0.584       0.589       0.558
# 3               85       Algeria       0.385       0.395       0.405
# 4               35       Andorra         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0    1993.000    1994.000    1995.000    1996.000    1997.000  ...
# 1       0.156       0.168       0.179       0.190       0.202  ...
# 2       0.543       0.542       0.551       0.558       0.571  ...
# 3       0.414       0.424       0.431       0.443       0.458  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0     2008.000     2009.000     2010.000     2011.000     2012.000
# ...
